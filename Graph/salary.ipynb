# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
salary= {2005: 93601, 2006: 93582, 2007: 102279, 2008: 81834, 2009: 53351, 2010: 49933, 2011: 53387, 2012: 52049, 2013: 56452, 2014: 51993, 2015: 52695, 2016: 62735, 2017: 61908, 2018: 67679, 2019: 71828, 2020: 72595, 2021: 84102, 2022: 97903}
quanity= {2005: 1836, 2006: 16229, 2007: 24000, 2008: 30627, 2009: 20989, 2010: 31930, 2011: 42282, 2012: 49309, 2013: 68149, 2014: 75828, 2015: 78934, 2016: 85740, 2017: 95811, 2018: 149308, 2019: 130763, 2020: 115116, 2021: 65205, 2022: 20685}
salary_name = {2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 75000, 2013: 0, 2014: 100000, 2015: 112500, 2016: 149196, 2017: 168478, 2018: 124755, 2019: 123061, 2020: 142053, 2021: 159965, 2022: 190160}
quanity_name = {2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 1, 2013: 0, 2014: 1, 2015: 1, 2016: 9, 2017: 34, 2018: 39, 2019: 51, 2020: 29, 2021: 44, 2022: 10}

# %%
labels = salary.keys()
x = np.arange(len(salary.keys()))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, salary.values(), width, label='Средняя з/п',color='orange')
rects2 = ax.bar(x + width/2, salary_name.values(), width, label='Средняя з/п DevOps',color='#69BDBA')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.axes.get_xaxis().set_ticks([])
ax.set_title('Уровень зарплат по годам')
ax.tick_params(axis='y', labelsize=8)
ax.set_xticks(x, labels, fontsize=8, rotation=90)
ax.legend(fontsize=11)
ax.yaxis.grid(True)
fig.tight_layout()

plt.show()

# %%
labels = salary.keys()
x = np.arange(len(salary.keys()))  # the label locations
width = 0.35  # the width of the bars

fig, (ax, ax_1) = plt.subplots(nrows=2, ncols=1)
rects1 = ax.bar(x - width/2, quanity.values(), width,color='orange')

rects1 = ax_1.bar(x - width/2, quanity_name.values(), width,color='#69BDBA')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.axes.get_xaxis().set_ticks([])
ax.set_title('Количество вакансий IT')
ax.tick_params(axis='y', labelsize=8)
ax.set_xticks(x, labels, fontsize=8, rotation=90)

ax.yaxis.grid(True)

ax_1.axes.get_xaxis().set_ticks([])
ax_1.set_title('Количество вакансий Devops')
ax_1.tick_params(axis='y', labelsize=8)
ax_1.set_xticks(x, labels, fontsize=8, rotation=90)

ax_1.yaxis.grid(True)

fig.tight_layout()

plt.show()
