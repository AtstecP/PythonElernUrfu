# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
data = {2015: {'Информационная безопасность': 32, 'Настройка сетевых подключений': 18, 'Настройка ПК': 18, 'Администрирование сетевого оборудования': 17, 'Настройка ПО': 17, 'Антивирусная защита сети': 16, 'Администрирование серверов Windows': 14, 'Администрирование серверов': 14, 'Информационные технологии': 11, 'Настройка серверов': 11},
2016: {'Информационная безопасность': 97, 'Настройка сетевых подключений': 50, 'Администрирование сетевого оборудования': 50, 'Информационные технологии': 40, 'Настройка ПО': 38, 'Администрирование серверов': 38, 'Настройка ПК': 37, 'Администрирование серверов Windows': 35, 'Технические системы и средства безопасности': 31, 'Настройка серверов': 29},
2017: {'Информационная безопасность': 196, 'Информационные технологии': 108, 'Администрирование сетевого оборудования': 83, 'Настройка сетевых подключений': 60, 'Администрирование серверов Windows': 57, 'Антивирусная защита сети': 57, 'Настройка ПО': 57, 'Настройка ПК': 53, 'Администрирование серверов': 51, 'Настройка серверов': 45},
2018: {'Информационная безопасность': 361, 'Администрирование сетевого оборудования': 169, 'Информационные технологии': 159, 'Настройка сетевых подключений': 144, 'Администрирование серверов Windows': 134, 'Настройка серверов': 120, 'Настройка ПК': 114, 'Антивирусная защита сети': 110, 'Настройка ПО': 108, 'Администрирование серверов': 101},
2019: {'Информационная безопасность': 493, 'Информационные технологии': 244, 'Администрирование сетевого оборудования': 204, 'Настройка сетевых подключений': 151, 'Администрирование серверов Windows': 140, 'Антивирусная защита сети': 140, 'Технические средства информационной защиты': 121, 'Настройка ПК': 114, 'Настройка ПО': 112, 'Настройка серверов': 106},
2020: {'Информационная безопасность': 867, 'Информационные технологии': 483, 'Администрирование сетевого оборудования': 262, 'Настройка сетевых подключений': 224, 'Технические средства информационной защиты': 213, 'Антивирусная защита сети': 192, 'Администрирование серверов Windows': 183, 'Средства криптографической защиты информации': 182, 'Linux': 179, 'Настройка ПК': 137},
2021: {'Информационная безопасность': 517, 'Информационные технологии': 260, 'Технические средства информационной защиты': 137, 'Администрирование сетевого оборудования': 135, 'Linux': 114, 'Настройка сетевых подключений': 110, 'Администрирование серверов Windows': 109, 'Средства криптографической защиты информации': 107, 'Антивирусная защита сети': 97, 'Настройка ПК': 84},
2022: {'Информационная безопасность': 198, 'Информационные технологии': 74, 'Администрирование сетевого оборудования': 49, 'Технические средства информационной защиты': 45, 'Средства криптографической защиты информации': 38, 'Пожарная безопасность': 35, 'Пользователь ПК': 34, 'Внедрение систем информационной безопасности': 31, 'Настройка сетевых подключений': 29, 'Linux': 29},
}








# data ={2015: { 'PHP': 1, 'PHP5': 1, 'CSS3': 1, 'reactjs': 1, 'Node.js': 1, 'react': 1, 'Symfony': 1, 'Fullstack': 3}
# ,2016: {'Full Stack': 10,'Java': 10,'Javascript': 18,'programmer': 10,'software': 10,'English': 10,'Remote': 10, 'Ruby': 9, 'Nginx': 6, 'jQuery': 6, 'HTML': 6, 'CSS': 6, 'JSON API': 6, 'CoffeeScript': 5, 'HAML': 5}
# ,2017: {'Java Full Stack': 12, 'remote work': 12, 'Business English': 12, 'Full Stack': 5, 'Linux': 5, 'Test Automation': 4, 'Java': 4, 'Python': 4, 'AWS': 4, 'Unix': 4}
# ,2018: {'JavaScript': 8, 'CSS': 7, 'PHP': 7, 'Fullstack': 7, 'Python': 7, 'Java': 6, 'MySQL': 6, 'Git': 6, 'jQuery': 6, 'Full stack': 4, 'back-end': 4, 'PHP developer': 5}
# ,2019: {'JavaScript': 29, 'HTML': 22, 'PostgreSQL': 21, 'PHP': 20, 'Git': 20, 'Fullstack': 35, 'React': 15, 'MySQL': 13, 'Node.js': 11}
# ,2020: {'JavaScript': 24, 'CSS': 19, 'HTML': 18, 'PHP': 17, 'Node.js': 15, 'Laravel': 12, 'MySQL': 12, 'Git': 12, 'PostgreSQL': 10, 'Full stack': 10}
# ,2021: {'JavaScript': 19, 'Node.js': 17, 'Git': 13, 'MySQL': 11, 'PHP': 10, 'CSS': 10, 'HTML5': 9, 'AngularJS': 9, 'SOLID': 9, 'Scrum': 9}
# ,2022: {'PHP': 6, 'JavaScript': 5, 'HTML': 5, 'CSS': 5,  'SQL': 4, 'Java': 3, 'web': 3, 'Git': 2, 'Fullstack': 6}}

years = list(range(2015,2023))

# %%
fig, ax = plt.subplots()
#print(data[1])
#ax.tick_params(axis='x', rotation=90)
#for item in data:
#    ax.bar( item.keys(), item.values())
skills = {}
print
for year in data.keys():
    for skill in data[year].keys():
        if not skills.__contains__(skill):
            skills[skill] = {'2015':0, '2016':0, '2017':0, '2018':0, '2019':0, '2020':0, '2021':0, '2022':0}
            #skills[skill] = {}
            skills[skill][year] = data[year][skill];

            # if  not skills[skill].__contains__(year):
            # else:
            #     skills[skill][year] += data[year][skill];
        else:
            if  not skills[skill].__contains__(year):
                skills[skill][year] = data[year][skill];
            else:
                skills[skill][year] += data[year][skill];
for i in skills.items():
    print(i)            
# for i, year in enumerate(years):
#     skills[year]={}
#     for skill in data[i]:
#         #skills[year].__contains__(skill):
#         skills[year][skill] = data[i][skill]
#ax.plot( skills['Adobe Photoshop'].keys(), skills['Adobe Photoshop'].values(), label='Adobe Photoshop')
#ax.plot( skills['Web-дизайн'].keys(), skills['Web-дизайн'].values(), label='Web-дизайн')
fig.set_size_inches(15,13)



for skill in skills.keys():
    ax.plot( skills[skill].keys(), skills[skill].values(), label=skill)
#ax.plot(2015, skills[1].values()  
#print(skills)  
ax.legend(fontsize=8)
ax.tick_params(axis='y', colors="#cfcfcf", labelsize=10)
ax.tick_params(axis='x', colors="#cfcfcf", labelsize=10)
ax.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')
plt.show()

#for i in skills:
#    print(skills[i].items())
# Out:
# ('Информационная безопасность', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 32, 2016: 97, 2017: 196, 2018: 361, 2019: 493, 2020: 867, 2021: 517, 2022: 198})
# ('Настройка сетевых подключений', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 18, 2016: 50, 2017: 60, 2018: 144, 2019: 151, 2020: 224, 2021: 110, 2022: 29})
# ('Настройка ПК', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 18, 2016: 37, 2017: 53, 2018: 114, 2019: 114, 2020: 137, 2021: 84})
# ('Администрирование сетевого оборудования', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 17, 2016: 50, 2017: 83, 2018: 169, 2019: 204, 2020: 262, 2021: 135, 2022: 49})
# ('Настройка ПО', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 17, 2016: 38, 2017: 57, 2018: 108, 2019: 112})
# ...

# %%
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']





fig, axs = plt.subplots(nrows=2, ncols=4)
#print(data[1])
#ax.tick_params(axis='x', rotation=90)
#for item in data:
#    ax.bar( item.keys(), item.values())
#fig.set_size_inches(40,20)
fig.set_size_inches(100,50, forward=True)
    
# for i, year in enumerate(years[:4]):
#         axs[i].bar(data[year].keys(), data[year].values() ,color='#1f77b4')
#         axs[i].tick_params(axis='x', rotation=45, labelsize=20)
#         axs[i].set_title(year, size=20)
#         #axs[0,i].tick_params(axis='y', colors="#cfcfcf", labelsize=10)
#         #axs[0,i].tick_params(axis='x', colors="#cfcfcf", labelsize=10)
#         axs[i].tick_params(axis='y', labelsize=15)
#         #axs[0,i].set_facecolor('#d1f7ff')
for i, year in enumerate(years[:4]):
        axs[0,i].bar(data[year].keys(), data[year].values() ,color='#1f77b4')
        axs[0,i].tick_params(axis='x', rotation=70, labelsize=40)
        axs[0,i].set_title(year, size=80)
        #axs[0,i].tick_params(axis='y', colors="#cfcfcf", labelsize=10)
        #axs[0,i].tick_params(axis='x', colors="#cfcfcf", labelsize=10)
        axs[0,i].tick_params(axis='y', labelsize=50)
        #axs[0,i].set_facecolor('#d1f7ff')
        
for i, year in enumerate(years[4:]):
        axs[1,i].bar(data[year].keys(), data[year].values(),color='#1f77b4' )
        axs[1,i].tick_params(axis='x', rotation=70, labelsize=40)
        axs[1,i].set_title(year, size=80) 
        #axs[1,i].tick_params(axis='y', colors="#cfcfcf", labelsize=10)
        #axs[1,i].tick_params(axis='x', colors="#cfcfcf", labelsize=10)
        axs[1,i].tick_params(axis='y', labelsize=50)
        #axs[1,i].set_facecolor('#d1f7ff')

#axs[0].bar(fruits, counts, label=bar_labels, color=bar_colors)

#ax.plot(2015, skills[1].values()  
#print(skills)  
# ax.legend(fontsize=8)

#ax.tick_params(axis='x', labelsize=20)
# ax.set_facecolor('#4E4E50')
#fig.patch.set_facecolor('#4E4E50')

#fig.patch.set_facecolor('#d1f7ff')
fig. tight_layout ()
plt.show()

#for i in skills:
#    print(skills[i].items())

# %%
fig, ( ax_1, ax ) = plt.subplots(nrows=1, ncols=2)
plt.style.use('_mpl-gallery-nogrid')
labels = ['Другие'] + list(share.keys())
x = [1 - sum(share.values())] + list(share.values())
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22',
          '#17becf', '#6633FF']
ax.pie(x, labels=labels, colors=colors, shadow=False, startangle=0, textprops={'fontsize': 12}, frame=True)

ax.axis('off')
ax.axis('equal')


fig.set_size_inches(17.5, 5.5)
plt.rcdefaults()
naming_list = [re.sub(re.compile(' |-'), '\n', key) for key in city.keys()]
x = (naming_list)
y_pos = np.arange(len(x))
error = np.random.rand(len(x))
ax_1.tick_params(axis='y', labelsize=10)
ax_1.tick_params(axis='x', labelsize=10)
ax_1.barh(y_pos, city.values(), xerr=error, align='center', color='#1f77b4')
ax_1.set_yticks(y_pos, labels=x)
ax_1.invert_yaxis()

ax_1.xaxis.grid(True)

# %%
fig, ( ax_1, ax ) = plt.subplots(nrows=1, ncols=2)
plt.style.use('_mpl-gallery-nogrid')
labels = ['Другие'] + list(share_name.keys())
x = [1 - sum(share_name.values())] + list(share.values())
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22',
          '#17becf', '#6633FF']
ax.pie(x, labels=labels, colors=colors, shadow=False, startangle=0, textprops={'fontsize': 12}, frame=True)

ax.axis('off')
ax.axis('equal')


fig.set_size_inches(17.5, 5.5)
plt.rcdefaults()
naming_list = [re.sub(re.compile(' |-'), '\n', key) for key in city_name.keys()]
x = (naming_list)
y_pos = np.arange(len(x))
error = np.random.rand(len(x))
ax_1.tick_params(axis='y', labelsize=10)
ax_1.tick_params(axis='x', labelsize=10)
ax_1.barh(y_pos, city_name.values(), xerr=error, align='center', color='#1f77b4')
ax_1.set_yticks(y_pos, labels=x)
ax_1.invert_yaxis()

ax_1.xaxis.grid(True)
