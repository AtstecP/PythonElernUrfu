# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
salary = {2005: 93601, 2006: 93582, 2007: 102279, 2008: 81834, 2009: 53351, 2010: 49933, 2011: 53387, 2012: 52049, 2013: 56452, 2014: 51993, 2015: 52695, 2016: 62735, 2017: 61908, 2018: 67679, 2019: 71828, 2020: 72595, 2021: 84102, 2022: 97903}
quanity =  {2005: 1836, 2006: 16229, 2007: 24000, 2008: 30627, 2009: 20989, 2010: 31930, 2011: 42282, 2012: 49309, 2013: 68149, 2014: 75828, 2015: 78934, 2016: 85740, 2017: 95811, 2018: 149308, 2019: 130763, 2020: 115116, 2021: 65205, 2022: 20685}
salary_name =  {2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 0, 2013: 0, 2014: 106155, 2015: 200298, 2016: 128773, 2017: 116660, 2018: 110383, 2019: 127558, 2020: 122546, 2021: 152585, 2022: 180548}
quanity_name =  {2005: 0, 2006: 0, 2007: 0, 2008: 0, 2009: 0, 2010: 0, 2011: 0, 2012: 0, 2013: 0, 2014: 2, 2015: 52, 2016: 223, 2017: 459, 2018: 939, 2019: 1104, 2020: 1119, 2021: 777, 2022: 208}
city = {'Киев': 97944, 'Москва': 85539, 'Санкт-Петербург': 72900, 'Минск': 70041, 'Новосибирск': 69034, 'Екатеринбург': 66848, 'Казань': 55723, 'Самара': 54699, 'Нижний Новгород': 53138, 'Краснодар': 53014}
share = {'Москва': 0.3137, 'Санкт-Петербург': 0.1106, 'Новосибирск': 0.0241, 'Минск': 0.0219, 'Казань': 0.0211, 'Нижний Новгород': 0.021, 'Алматы': 0.019, 'Екатеринбург': 0.0182, 'Ростов-на-Дону': 0.0182, 'Краснодар': 0.0159}
city_name = {'Киев': 180529, 'Москва': 150430, 'Нижний Новгород': 146809, 'Самара': 137482, 'Санкт-Петербург': 133006, 'Новосибирск': 129779, 'Минск': 128552, 'Казань': 125514, 'Екатеринбург': 125262, 'Краснодар': 112995}
share_name = {'Москва': 0.301, 'Санкт-Петербург': 0.1505, 'Новосибирск': 0.0528, 'Минск': 0.036, 'Киев': 0.0332, 'Алматы': 0.0281, 'Казань': 0.025, 'Екатеринбург': 0.0229, 'Ростов-на-Дону': 0.0158, 'Омск': 0.0156}

# %%
labels = salary.keys()
x = np.arange(len(salary.keys()))  # the label locations
width = 0.35  # the width of the bars
fig.set_size_inches(17.5, 5.5)

fig, ax = plt.subplots()
ax.bar(x - width/2, salary.values(), width, label='Средняя з/п',color='#ffff')
ax.bar(x + width/2, salary_name.values(), width, label='Средняя з/п специалист тех поддержки ',color='#9b2e44')
ax.set_title('Уровень зарплат', color='#cfcfcf', size=15)
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.axes.get_xaxis().set_ticks([])
ax.tick_params(axis='y', labelsize=8)
ax.set_xticks(x, labels, fontsize=8, rotation=45, color='#cfcfcf')

ax.legend(fontsize=11)
ax.yaxis.grid(True)
fig.tight_layout()


ax.tick_params(axis='y', colors="#cfcfcf")
"""
ax.spines['bottom'].set_color('#cfcfcf')
ax.spines['top'].set_color('#cfcfcf')
ax.spines['left'].set_color('#cfcfcf')
ax.spines['right'].set_color('#cfcfcf')"""
ax.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')

plt.show()

# %%
labels = salary.keys()
x = np.arange(len(salary.keys()))  # the label locations
width = 0.35  # the width of the bars
fig.set_size_inches(17.5, 5.5)

fig, (ax, ax_1) = plt.subplots(nrows=2, ncols=1)
rects1 = ax.bar(x - width/2, quanity.values(), width,color='#ffff')

rects1 = ax_1.bar(x - width/2, quanity_name.values(), width,color='#9b2e44')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.axes.get_xaxis().set_ticks([])
ax.set_title('Количество вакансий IT', color='#cfcfcf', size=15)
ax.tick_params(axis='y', labelsize=10, colors="#cfcfcf")
ax.set_xticks(x, labels, fontsize=8, rotation=45, color="#cfcfcf")

ax.yaxis.grid(True)

ax_1.axes.get_xaxis().set_ticks([])
ax_1.set_title('Количество вакансий FullStack', color='#cfcfcf', size=15)
ax_1.tick_params(axis='y', labelsize=8, colors="#cfcfcf")
ax_1.set_xticks(x, labels, fontsize=8, rotation=45, color="#cfcfcf")

ax_1.yaxis.grid(True)


ax.set_facecolor('#4E4E50')
ax_1.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')


fig.tight_layout()

plt.show()

# %%
fig, ( ax_1, ax ) = plt.subplots(nrows=1, ncols=2)
plt.style.use('_mpl-gallery-nogrid')
labels = ['Другие'] + list(share.keys())
x = [1 - sum(share.values())] + list(share.values())
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22',
          '#17becf', '#6633FF']
ax.pie(x, labels=labels, colors=colors, shadow=False, startangle=0, textprops={'fontsize': 12, 'color':'#cfcfcf',}, frame=True)
ax.axis('off')
ax.axis('equal')


fig.set_size_inches(17.5, 5.5)
plt.rcdefaults()
naming_list = [re.sub(re.compile(' |-'), '\n', key) for key in city.keys()]
x = (naming_list)
y_pos = np.arange(len(x))
error = np.random.rand(len(x))
ax_1.tick_params(axis='y', labelsize=10)
ax_1.tick_params(axis='x', labelsize=12, colors='#cfcfcf')
ax_1.barh(y_pos, city.values(), xerr=error, align='center', color='#9b2e44')
ax_1.set_yticks(y_pos, labels=x, color="#cfcfcf")
ax_1.invert_yaxis()


ax.set_facecolor('#4E4E50')
ax_1.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')

ax_1.xaxis.grid(True)

# %%
fig, ( ax_1, ax ) = plt.subplots(nrows=1, ncols=2)
plt.style.use('_mpl-gallery-nogrid')
labels = ['Другие'] + list(share_name.keys())
x = [1 - sum(share_name.values())] + list(share_name.values())
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22',
          '#17becf', '#6633FF']
ax.pie(x, labels=labels, colors=colors, shadow=False, startangle=0, textprops={'fontsize': 12, 'color':'#cfcfcf',}, frame=True)
ax.axis('off')
ax.axis('equal')


fig.set_size_inches(17.5, 5.5)
plt.rcdefaults()
naming_list = [re.sub(re.compile(' |-'), '\n', key) for key in city_name.keys()]
x = (naming_list)
y_pos = np.arange(len(x))
error = np.random.rand(len(x))
ax_1.tick_params(axis='y', labelsize=10)
ax_1.tick_params(axis='x', labelsize=12, colors='#cfcfcf')
ax_1.barh(y_pos, city_name.values(), xerr=error, align='center', color='#9b2e44')
ax_1.set_yticks(y_pos, labels=x, color="#cfcfcf")
ax_1.invert_yaxis()


ax.set_facecolor('#4E4E50')
ax_1.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')

ax_1.xaxis.grid(True)
