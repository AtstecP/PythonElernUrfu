# %%
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
data = {2015: {'Техническая поддержка': 99, 'Пользователь ПК': 34, 'Работа с оргтехникой': 26, 'Установка ПО': 26, 'Настройка сетевых подключений': 22, 'Администрирование': 18, 'Обновление ПО': 18, 'Helpdesk': 17, 'Администрирование серверов Windows': 16, 'Настройка ПК': 15},
2016: {'Техническая поддержка': 312, 'Helpdesk': 101, 'Пользователь ПК': 68, 'Информационные технологии': 63, 'Консультирование клиентов по телефону': 57, 'Настройка сетевых подключений': 53, 'Настройка ПО': 52, 'Английский язык': 52, 'Настройка ПК': 52, 'Работа в команде': 49},
2017: {'Техническая поддержка': 573, 'Helpdesk': 218, 'Консультирование клиентов по телефону': 150, 'Информационные технологии': 136, 'Пользователь ПК': 128, 'Грамотная речь': 125, 'Настройка ПО': 118, 'Работа в команде': 118, 'Customer Support': 100, 'Настройка сетевых подключений': 97},
2018: {'Техническая поддержка': 1056, 'Helpdesk': 338, 'Консультирование клиентов по телефону': 290, 'Информационные технологии': 256, 'Грамотная речь': 247, 'Пользователь ПК': 241, 'Настройка ПО': 217, 'Работа в команде': 215, 'Настройка ПК': 212, 'Customer Support': 203},
2019: {'Техническая поддержка': 1446, 'Helpdesk': 493, 'Информационные технологии': 388, 'Настройка ПК': 374, 'Настройка ПО': 365, 'Грамотная речь': 361, 'Пользователь ПК': 331, 'Настройка сетевых подключений': 325, 'Консультирование клиентов по телефону': 324, 'Работа в команде': 288},
2020: {'Техническая поддержка': 1865, 'Настройка ПК': 557, 'Настройка сетевых подключений': 451, 'Пользователь ПК': 441, 'Helpdesk': 407, 'Грамотная речь': 405, 'Информационные технологии': 400, 'Настройка ПО': 388, 'Работа в команде': 338, 'Администрирование сетевого оборудования': 309},
2021: {'Техническая поддержка': 1348, 'Грамотная речь': 445, 'Работа в команде': 380, 'Настройка ПК': 362, 'Настройка сетевых подключений': 336, 'Настройка ПО': 313, 'Helpdesk': 308, 'Пользователь ПК': 255, 'Информационные технологии': 237, 'Английский язык': 202},
2022: {'Техническая поддержка': 390, 'Настройка ПК': 151, 'Настройка ПО': 126, 'Настройка сетевых подключений': 106, 'Helpdesk': 84, 'Работа в команде': 81, 'Грамотная речь': 80, 'Информационные технологии': 80, 'Администрирование сетевого оборудования': 78, 'Администрирование': 73},
}











# data ={2015: { 'PHP': 1, 'PHP5': 1, 'CSS3': 1, 'reactjs': 1, 'Node.js': 1, 'react': 1, 'Symfony': 1, 'Fullstack': 3}
# ,2016: {'Full Stack': 10,'Java': 10,'Javascript': 18,'programmer': 10,'software': 10,'English': 10,'Remote': 10, 'Ruby': 9, 'Nginx': 6, 'jQuery': 6, 'HTML': 6, 'CSS': 6, 'JSON API': 6, 'CoffeeScript': 5, 'HAML': 5}
# ,2017: {'Java Full Stack': 12, 'remote work': 12, 'Business English': 12, 'Full Stack': 5, 'Linux': 5, 'Test Automation': 4, 'Java': 4, 'Python': 4, 'AWS': 4, 'Unix': 4}
# ,2018: {'JavaScript': 8, 'CSS': 7, 'PHP': 7, 'Fullstack': 7, 'Python': 7, 'Java': 6, 'MySQL': 6, 'Git': 6, 'jQuery': 6, 'Full stack': 4, 'back-end': 4, 'PHP developer': 5}
# ,2019: {'JavaScript': 29, 'HTML': 22, 'PostgreSQL': 21, 'PHP': 20, 'Git': 20, 'Fullstack': 35, 'React': 15, 'MySQL': 13, 'Node.js': 11}
# ,2020: {'JavaScript': 24, 'CSS': 19, 'HTML': 18, 'PHP': 17, 'Node.js': 15, 'Laravel': 12, 'MySQL': 12, 'Git': 12, 'PostgreSQL': 10, 'Full stack': 10}
# ,2021: {'JavaScript': 19, 'Node.js': 17, 'Git': 13, 'MySQL': 11, 'PHP': 10, 'CSS': 10, 'HTML5': 9, 'AngularJS': 9, 'SOLID': 9, 'Scrum': 9}
# ,2022: {'PHP': 6, 'JavaScript': 5, 'HTML': 5, 'CSS': 5,  'SQL': 4, 'Java': 3, 'web': 3, 'Git': 2, 'Fullstack': 6}}

years = list(range(2015,2023))

# %%
fig, ax = plt.subplots()
#print(data[1])
#ax.tick_params(axis='x', rotation=90)
#for item in data:
#    ax.bar( item.keys(), item.values())
skills = {}
print
for year in data.keys():
    for skill in data[year].keys():
        if not skills.__contains__(skill):
            skills[skill] = {'2015':0, '2016':0, '2017':0, '2018':0, '2019':0, '2020':0, '2021':0, '2022':0}
            #skills[skill] = {}
            skills[skill][year] = data[year][skill];

            # if  not skills[skill].__contains__(year):
            # else:
            #     skills[skill][year] += data[year][skill];
        else:
            if  not skills[skill].__contains__(year):
                skills[skill][year] = data[year][skill];
            else:
                skills[skill][year] += data[year][skill];
for i in skills.items():
    print(i)            
# for i, year in enumerate(years):
#     skills[year]={}
#     for skill in data[i]:
#         #skills[year].__contains__(skill):
#         skills[year][skill] = data[i][skill]
#ax.plot( skills['Adobe Photoshop'].keys(), skills['Adobe Photoshop'].values(), label='Adobe Photoshop')
#ax.plot( skills['Web-дизайн'].keys(), skills['Web-дизайн'].values(), label='Web-дизайн')
fig.set_size_inches(15,13)



for skill in skills.keys():
    ax.plot( skills[skill].keys(), skills[skill].values(), label=skill)
#ax.plot(2015, skills[1].values()  
#print(skills)  
ax.legend(fontsize=8)
ax.tick_params(axis='y', colors="#cfcfcf", labelsize=10)
ax.tick_params(axis='x', colors="#cfcfcf", labelsize=10)
ax.set_facecolor('#4E4E50')
fig.patch.set_facecolor('#4E4E50')
plt.show()

#for i in skills:
#    print(skills[i].items())
# Out:
# ('Python', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 204, 2016: 857, 2017: 1269, 2018: 2608, 2019: 2721, 2020: 3324, 2021: 2281, 2022: 651})
# ('Linux', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 74, 2016: 268, 2017: 461, 2018: 827, 2019: 921, 2020: 1166, 2021: 772, 2022: 239})
# ('JavaScript', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 63, 2016: 379, 2017: 456, 2018: 960, 2019: 607, 2020: 643, 2021: 387, 2022: 73})
# ('Django Framework', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 58, 2017: 341, 2019: 598, 2020: 755, 2021: 512, 2022: 124})
# ('Git', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 51, 2016: 388, 2017: 430, 2018: 1031, 2019: 831, 2020: 1163, 2021: 814, 2022: 228})
# ('MySQL', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 48, 2017: 295, 2018: 719, 2019: 430, 2020: 479, 2021: 257})
# ('PostgreSQL', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 39, 2017: 375, 2018: 669, 2019: 714, 2020: 942, 2021: 600, 2022: 190})
# ('Java', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 35, 2016: 244, 2018: 682, 2019: 346})
# ('SQL', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 33, 2016: 293, 2017: 295, 2018: 837, 2019: 755, 2020: 928, 2021: 713, 2022: 250})
# ('HTML', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2015: 32, 2016: 218, 2018: 689})
# ('PHP', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2016: 256, 2017: 282})
# ('jQuery', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2016: 244})
# ('CSS', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2016: 236, 2017: 248})
# ('C++', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2018: 661, 2019: 388, 2020: 459, 2021: 243})
# ('Bash', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2020: 397, 2022: 77})
# ('Docker', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2021: 253, 2022: 118})
# ('Английский язык', {'2015': 0, '2016': 0, '2017': 0, '2018': 0, '2019': 0, '2020': 0, '2021': 0, '2022': 0, 2022: 94})

# %%
fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']


#font = {'family' : 'Comfortaa',
        
plt.rc('font', **font)


fig, axs = plt.subplots(nrows=2, ncols=4)
#print(data[1])
#ax.tick_params(axis='x', rotation=90)
#for item in data:
#    ax.bar( item.keys(), item.values())
#fig.set_size_inches(40,20)
fig.set_size_inches(40,20, forward=True)


# for i, year in enumerate(years[:4]):
#         axs[i].bar(data[year].keys(), data[year].values() ,color='#1f77b4')
#         axs[i].tick_params(axis='x', rotation=45, labelsize=20)
#         axs[i].set_title(year, size=20)
#         #axs[0,i].tick_params(axis='y', colors="#cfcfcf", labelsize=10)
#         #axs[0,i].tick_params(axis='x', colors="#cfcfcf", labelsize=10)
#         axs[i].tick_params(axis='y', labelsize=15)
#         #axs[0,i].set_facecolor('#d1f7ff')
for i, year in enumerate(years[:4]):
        axs[0,i].bar(data[year].keys(), data[year].values() ,color='#e0b567')
        axs[0,i].tick_params(axis='x', rotation=45, labelsize=18)
        axs[0,i].set_title(year, size=30,color ="#C1CAD2")
        axs[0,i].tick_params(axis='y', colors="#C1CAD2", labelsize=10)
        axs[0,i].tick_params(axis='x', colors="#C1CAD2", labelsize=20)
        axs[0,i].tick_params(axis='y', labelsize=20)
        axs[0,i].set_facecolor('#0e1117')
        
for i, year in enumerate(years[4:]):
        axs[1,i].bar(data[year].keys(), data[year].values(),color='#e0b567' )
        axs[1,i].tick_params(axis='x', rotation=45, labelsize=20)
        axs[1,i].set_title(year, size=30,color ="#C1CAD2") 
        axs[1,i].tick_params(axis='y', colors="#C1CAD2", labelsize=10)
        axs[1,i].tick_params(axis='x', colors="#C1CAD2", labelsize=20)
        axs[1,i].tick_params(axis='y', labelsize=20)
        axs[1,i].set_facecolor('#0e1117')

#axs[0].bar(fruits, counts, label=bar_labels, color=bar_colors)

#ax.plot(2015, skills[1].values()  
#print(skills)  
# ax.legend(fontsize=8)

#ax.tick_params(axis='x', labelsize=20)
# ax.set_facecolor('#4E4E50')
#fig.patch.set_facecolor('#4E4E50')

fig.patch.set_facecolor('#0e1117')
fig. tight_layout ()
plt.show()

#for i in skills:
#    print(skills[i].items())

# %%
print('<div><h2  style="text-align: center; margin: 0 20% 0 20%">Список самых популярных скиллов по годам</h2></div><div style="margin: 1% 20% 0 20%;">')
for year in data.keys():
    print(f'<p><strong>{year}:</strong> ',end='')
    for skill in data[year].keys():
         print(f'{skill}({data[year][skill]}), ',end='')
    print('</p>')
print('</div>')
# Out:
# <div><h2  style="text-align: center; margin: 0 20% 0 20%">Список самых популярных скиллов по годам</h2></div><div style="margin: 1% 20% 0 20%;">
# <p><strong>2015:</strong> Техническая поддержка(99), Пользователь ПК(34), Работа с оргтехникой(26), Установка ПО(26), Настройка сетевых подключений(22), Администрирование(18), Обновление ПО(18), Helpdesk(17), Администрирование серверов Windows(16), Настройка ПК(15), </p>
# <p><strong>2016:</strong> Техническая поддержка(312), Helpdesk(101), Пользователь ПК(68), Информационные технологии(63), Консультирование клиентов по телефону(57), Настройка сетевых подключений(53), Настройка ПО(52), Английский язык(52), Настройка ПК(52), Работа в команде(49), </p>
# <p><strong>2017:</strong> Техническая поддержка(573), Helpdesk(218), Консультирование клиентов по телефону(150), Информационные технологии(136), Пользователь ПК(128), Грамотная речь(125), Настройка ПО(118), Работа в команде(118), Customer Support(100), Настройка сетевых подключений(97), </p>
# <p><strong>2018:</strong> Техническая поддержка(1056), Helpdesk(338), Консультирование клиентов по телефону(290), Информационные технологии(256), Грамотная речь(247), Пользователь ПК(241), Настройка ПО(217), Работа в команде(215), Настройка ПК(212), Customer Support(203), </p>
# <p><strong>2019:</strong> Техническая поддержка(1446), Helpdesk(493), Информационные технологии(388), Настройка ПК(374), Настройка ПО(365), Грамотная речь(361), Пользователь ПК(331), Настройка сетевых подключений(325), Консультирование клиентов по телефону(324), Работа в команде(288), </p>
# <p><strong>2020:</strong> Техническая поддержка(1865), Настройка ПК(557), Настройка сетевых подключений(451), Пользователь ПК(441), Helpdesk(407), Грамотная речь(405), Информационные технологии(400), Настройка ПО(388), Работа в команде(338), Администрирование сетевого оборудования(309), </p>
# <p><strong>2021:</strong> Техническая поддержка(1348), Грамотная речь(445), Работа в команде(380), Настройка ПК(362), Настройка сетевых подключений(336), Настройка ПО(313), Helpdesk(308), Пользователь ПК(255), Информационные технологии(237), Английский язык(202), </p>
# <p><strong>2022:</strong> Техническая поддержка(390), Настройка ПК(151), Настройка ПО(126), Настройка сетевых подключений(106), Helpdesk(84), Работа в команде(81), Грамотная речь(80), Информационные технологии(80), Администрирование сетевого оборудования(78), Администрирование(73), </p>
# </div>

# %%
print('<div><h2  style="text-align: center; margin: 0 20% 40px 20%">Список самых популярных скиллов по годам</h2></div><div style="margin: 0 5% 0 5%">')
for year in data.keys():
    
    pos = 'right'
    if year%2 == 0:
        pos = 'right'
    else:
        pos = 'left'
    
    print(f'<div style="width: 40%;float:{pos};  margin: 0 40px 20px 40px"><table  class="table table-bordered">')
    print(f'<h3><b>{year}</b></h3>')
    for skill in data[year].keys():
        print('<tr>')
        print(f'<th>{skill}</th><th>{data[year][skill]}</th>',end='')
        print('</tr>')
    print('</table></div>')
print('</div>')
# Out:
# <div><h2  style="text-align: center; margin: 0 20% 40px 20%">Список самых популярных скиллов по годам</h2></div><div style="margin: 0 5% 0 5%">
# <div style="width: 40%;float:left;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2015</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>99</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>34</th></tr>
# <tr>
# <th>Работа с оргтехникой</th><th>26</th></tr>
# <tr>
# <th>Установка ПО</th><th>26</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>22</th></tr>
# <tr>
# <th>Администрирование</th><th>18</th></tr>
# <tr>
# <th>Обновление ПО</th><th>18</th></tr>
# <tr>
# <th>Helpdesk</th><th>17</th></tr>
# <tr>
# <th>Администрирование серверов Windows</th><th>16</th></tr>
# <tr>
# <th>Настройка ПК</th><th>15</th></tr>
# </table></div>
# <div style="width: 40%;float:right;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2016</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>312</th></tr>
# <tr>
# <th>Helpdesk</th><th>101</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>68</th></tr>
# <tr>
# <th>Информационные технологии</th><th>63</th></tr>
# <tr>
# <th>Консультирование клиентов по телефону</th><th>57</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>53</th></tr>
# <tr>
# <th>Настройка ПО</th><th>52</th></tr>
# <tr>
# <th>Английский язык</th><th>52</th></tr>
# <tr>
# <th>Настройка ПК</th><th>52</th></tr>
# <tr>
# <th>Работа в команде</th><th>49</th></tr>
# </table></div>
# <div style="width: 40%;float:left;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2017</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>573</th></tr>
# <tr>
# <th>Helpdesk</th><th>218</th></tr>
# <tr>
# <th>Консультирование клиентов по телефону</th><th>150</th></tr>
# <tr>
# <th>Информационные технологии</th><th>136</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>128</th></tr>
# <tr>
# <th>Грамотная речь</th><th>125</th></tr>
# <tr>
# <th>Настройка ПО</th><th>118</th></tr>
# <tr>
# <th>Работа в команде</th><th>118</th></tr>
# <tr>
# <th>Customer Support</th><th>100</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>97</th></tr>
# </table></div>
# <div style="width: 40%;float:right;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2018</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>1056</th></tr>
# <tr>
# <th>Helpdesk</th><th>338</th></tr>
# <tr>
# <th>Консультирование клиентов по телефону</th><th>290</th></tr>
# <tr>
# <th>Информационные технологии</th><th>256</th></tr>
# <tr>
# <th>Грамотная речь</th><th>247</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>241</th></tr>
# <tr>
# <th>Настройка ПО</th><th>217</th></tr>
# <tr>
# <th>Работа в команде</th><th>215</th></tr>
# <tr>
# <th>Настройка ПК</th><th>212</th></tr>
# <tr>
# <th>Customer Support</th><th>203</th></tr>
# </table></div>
# <div style="width: 40%;float:left;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2019</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>1446</th></tr>
# <tr>
# <th>Helpdesk</th><th>493</th></tr>
# <tr>
# <th>Информационные технологии</th><th>388</th></tr>
# <tr>
# <th>Настройка ПК</th><th>374</th></tr>
# <tr>
# <th>Настройка ПО</th><th>365</th></tr>
# <tr>
# <th>Грамотная речь</th><th>361</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>331</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>325</th></tr>
# <tr>
# <th>Консультирование клиентов по телефону</th><th>324</th></tr>
# <tr>
# <th>Работа в команде</th><th>288</th></tr>
# </table></div>
# <div style="width: 40%;float:right;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2020</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>1865</th></tr>
# <tr>
# <th>Настройка ПК</th><th>557</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>451</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>441</th></tr>
# <tr>
# <th>Helpdesk</th><th>407</th></tr>
# <tr>
# <th>Грамотная речь</th><th>405</th></tr>
# <tr>
# <th>Информационные технологии</th><th>400</th></tr>
# <tr>
# <th>Настройка ПО</th><th>388</th></tr>
# <tr>
# <th>Работа в команде</th><th>338</th></tr>
# <tr>
# <th>Администрирование сетевого оборудования</th><th>309</th></tr>
# </table></div>
# <div style="width: 40%;float:left;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2021</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>1348</th></tr>
# <tr>
# <th>Грамотная речь</th><th>445</th></tr>
# <tr>
# <th>Работа в команде</th><th>380</th></tr>
# <tr>
# <th>Настройка ПК</th><th>362</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>336</th></tr>
# <tr>
# <th>Настройка ПО</th><th>313</th></tr>
# <tr>
# <th>Helpdesk</th><th>308</th></tr>
# <tr>
# <th>Пользователь ПК</th><th>255</th></tr>
# <tr>
# <th>Информационные технологии</th><th>237</th></tr>
# <tr>
# <th>Английский язык</th><th>202</th></tr>
# </table></div>
# <div style="width: 40%;float:right;  margin: 0 40px 20px 40px"><table  class="table table-bordered">
# <h3><b>2022</b></h3>
# <tr>
# <th>Техническая поддержка</th><th>390</th></tr>
# <tr>
# <th>Настройка ПК</th><th>151</th></tr>
# <tr>
# <th>Настройка ПО</th><th>126</th></tr>
# <tr>
# <th>Настройка сетевых подключений</th><th>106</th></tr>
# <tr>
# <th>Helpdesk</th><th>84</th></tr>
# <tr>
# <th>Работа в команде</th><th>81</th></tr>
# <tr>
# <th>Грамотная речь</th><th>80</th></tr>
# <tr>
# <th>Информационные технологии</th><th>80</th></tr>
# <tr>
# <th>Администрирование сетевого оборудования</th><th>78</th></tr>
# <tr>
# <th>Администрирование</th><th>73</th></tr>
# </table></div>
# </div>
